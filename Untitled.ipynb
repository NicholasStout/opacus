# %%
import numpy as np
from scipy.stats import gamma, uniform, norm
from concurrent.futures import ThreadPoolExecutor, as_completed
import itertools
from opacus.accountants.analysis.rdp import compute_rdp, get_privacy_spent
import math


delta_values = [1e-5, 1e-10]
epsilons = np.array([0.5, 0.7, 0.9])  # Range of epsilon
T_value = 1000  # Fixed T value
sensitivity_values = np.arange(0.1, 1.1, 0.3)  # Sensitivity ranging from 0.1 to 5 with an increment of 0.1

# Define reasonable ranges for the other parameters
k_values = np.array([0.1, 0.3, 0.5, 0.7])#, 0.5, 0.7, 0.9,1,2])
theta_values = np.array([0.3, 0.5, 0.7, 0.9])#,2,3,5,7.5,9])
a_values = np.arange(0, 1.1, 0.3)
b_values = np.arange(1, 1.1, 0.3)  # Ensure b > a
mu_values = np.arange(0, 1.1, 0.3)
sigma_values = np.arange(0.1, 1.1, 0.3)
l_values = np.arange(0.1, 1.1, 0.3)
u_values = np.arange(1, 1.1, 0.3)
#t_values = np.arange(0.01, 0.51, 0.15)
lamda_values=np.array([1, 2, 3, 5])


# PDF functions based on the given distributions
def gamma_pdf(k, theta, x):
    return gamma.pdf(x, k, scale=theta)

def uniform_pdf(a, b, x):
    return uniform.pdf(x, loc=a, scale=b - a)

def truncated_normal_pdf(mu, sigma, l, u, x):
    return norm.pdf(x, mu, sigma) / (norm.cdf(u, mu, sigma) - norm.cdf(l, mu, sigma))

# Objective function
def objective_function(k, theta, a, b, mu, sigma, l, u):
    gamma_expect = k * theta
    uniform_expect = (a + b) / 2
    normal_expect = mu + sigma * (norm.pdf((l - mu) / sigma) - norm.pdf((u - mu) / sigma)) / (norm.cdf((u - mu) / sigma) - norm.cdf((l - mu) / sigma))
    return gamma_expect + uniform_expect + normal_expect

# MGF functions
def mgf_gamma(k, theta, t):
    if t * theta >= 1:
        return np.nan  # Prevent undefined behavior
    return (1 - t * theta) ** (-k)

def mgf_uniform(a, b, t):
    if t == 0:
        return 1  # Special case for t = 0
    return (np.exp(b * t) - np.exp(a * t)) / (t * (b - a))

def mgf_truncated_normal(mu, sigma, l, u, t):
    alpha = (l - mu) / sigma
    beta = (u - mu) / sigma
    num = norm.cdf(beta - sigma * t) - norm.cdf(alpha - sigma * t)
    den = norm.cdf(beta) - norm.cdf(alpha)
    return np.exp((mu * t + 0.5 * sigma ** 2 * t ** 2)/2) * num / den

def MGF_PLRV(k, theta, a, b, mu, sigma, l, u, T_value, t):
    #return np.prod([mgf_gamma(k, theta, t), mgf_uniform(a, b, t), mgf_truncated_normal(mu, sigma, l, u, t)]) ** T_value
    return mgf_truncated_normal(mu, sigma, l, u, t) ** T_value

# Grid search for one epsilon value
def grid_search_for_epsilon(lamda_values, epsilon, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values):
    best_params = None
    best_value = -np.inf
    min_lemma1 = float('inf')
    
    for lamda, sensitivity, k, theta, a, b, mu, sigma, l, u, delta in itertools.product(
            lamda_values, sensitivity_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values, delta_values):
        
        # Apply constraints
        if b > a and u > l and sigma > 0 and theta > 0:
            obj_value = objective_function(k, theta, a, b, mu, sigma, l, u)
            
            # Compute the terms in the numerator
            term1 = (lamda + 1) * MGF_PLRV(k, theta, a, b, mu, sigma, l, u, T_value, lamda * sensitivity)
            term2 = lamda * MGF_PLRV(k, theta, a, b, mu, sigma, l, u, T_value, -(lamda + 1) * sensitivity)
            numerator = term1 + term2

            # Compute the denominator
            denominator = (2 * lamda + 1) * np.exp(lamda * (epsilon/T_value))

            # Compute delta for the current lambda
            lemma1 = numerator / denominator

            L = obj_value - (lemma1)
            
            if lemma1 <= delta:
                L = -np.inf
            
            test_ep = (lemma1/(lamda*sensitivity)+math.log(1/delta)/(lamda*sensitivity))
            # Keep track of the minimum delta
            if L > best_value:
                best_value = L
                best_params = {'epsilon': epsilon, 'T': T_value, 'sensitivity': sensitivity, 'k': k, 'theta': theta, 'a': a, 'b': b, 'mu': mu, 'sigma': sigma, 'l': l, 'u': u, 'lambda': lamda}
    return best_params, best_value


# Split epsilon values evenly across threads
def split_epsilons_across_threads(epsilons, num_threads):
    split_size = len(epsilons) // num_threads
    epsilon_splits = [epsilons[i:i + split_size] for i in range(0, len(epsilons), split_size)]
    return epsilon_splits

# Parallel grid search, assigning unique epsilon subsets to each thread
def grid_search_concurrent(lamda_values, epsilon_splits, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values):
    print("Starting grid search...")
    results = []
    with ThreadPoolExecutor(max_workers=len(epsilon_splits)) as executor:
        futures = []
        for epsilon_subset in epsilon_splits:
            futures.append(executor.submit(grid_search_for_epsilon_subset,lamda_values, epsilon_subset, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values))
        
        for future in as_completed(futures):
            results.extend(future.result())
    
    return results

# Grid search over an epsilon subset
def grid_search_for_epsilon_subset(lamda_values, epsilon_subset, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values):
    subset_results = []
    for epsilon in epsilon_subset:
        best_params, best_value = grid_search_for_epsilon(lamda_values, epsilon, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values)
        subset_results.append({'epsilon': epsilon, 'best_params': best_params, 'best_value': best_value})
    return subset_results

# Run the search with multiple threads, each with its own epsilon subset
num_threads = 2  # You can adjust this number based on your system's capabilities
epsilon_splits = split_epsilons_across_threads(epsilons, num_threads)

# Perform the grid search
best_solutions = grid_search_concurrent(
    lamda_values=lamda_values,
    epsilon_splits=epsilon_splits, 
    T_value=T_value,
    sensitivity_values=sensitivity_values,
    delta_values=delta_values,
    k_values=k_values,
    theta_values=theta_values,
    a_values=a_values,
    b_values=b_values,
    mu_values=mu_values,
    sigma_values=sigma_values,
    l_values=l_values,
    u_values=u_values
)

# Display the best solutions
for result in best_solutions:
    print(f"Epsilon: {result['epsilon']}, Best Parameters: {result['best_params']}, Best_value: {result['best_value']}")
# Out:
# Starting grid search...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 118, in grid_search_concurrent(lamda_values, epsilon_splits, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values)
#     116     futures.append(executor.submit(grid_search_for_epsilon_subset,lamda_values, epsilon_subset, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values))
# --> 118 for future in as_completed(futures):
#     119     results.extend(future.result())
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:243, in as_completed(fs, timeout)
#     239         raise TimeoutError(
#     240                 '%d (of %d) futures unfinished' % (
#     241                 len(pending), total_futures))
# --> 243 waiter.event.wait(wait_timeout)
#     245 with waiter.lock:
#
# File /usr/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     354 if timeout is None:
# --> 355     waiter.acquire()
#     356     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[2], line 136
#     135 # Perform the grid search
# --> 136 best_solutions = grid_search_concurrent(
#     137     lamda_values=lamda_values,
#     138     epsilon_splits=epsilon_splits,
#     139     T_value=T_value,
#     140     sensitivity_values=sensitivity_values,
#     141     delta_values=delta_values,
#     142     k_values=k_values,
#     143     theta_values=theta_values,
#     144     a_values=a_values,
#     145     b_values=b_values,
#     146     mu_values=mu_values,
#     147     sigma_values=sigma_values,
#     148     l_values=l_values,
#     149     u_values=u_values
#     150 )
#     152 # Display the best solutions
#
# Cell In[2], line 113, in grid_search_concurrent(lamda_values, epsilon_splits, T_value, sensitivity_values, delta_values, k_values, theta_values, a_values, b_values, mu_values, sigma_values, l_values, u_values)
#     112 results = []
# --> 113 with ThreadPoolExecutor(max_workers=len(epsilon_splits)) as executor:
#     114     futures = []
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:647, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     646 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 647     self.shutdown(wait=True)
#     648     return False
#
# File /usr/lib/python3.12/concurrent/futures/thread.py:238, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     237 for t in self._threads:
# --> 238     t.join()
#
# File /usr/lib/python3.12/threading.py:1147, in Thread.join(self, timeout)
#    1146 if timeout is None:
# -> 1147     self._wait_for_tstate_lock()
#    1148 else:
#    1149     # the behavior of a negative timeout isn't documented, but
#    1150     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#
# File /usr/lib/python3.12/threading.py:1167, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1166 try:
# -> 1167     if lock.acquire(block, timeout):
#    1168         lock.release()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2144, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2143     else:
# -> 2144         stb = self.InteractiveTB.structured_traceback(
#    2145             etype, value, tb, tb_offset=tb_offset
#    2146         )
#    2148 except Exception:
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1172 """Return a nice text document describing the traceback."""
# -> 1173 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                        tb_offset)
#    1176 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1088, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1087         skipped = 0
# -> 1088     frames.append(self.format_record(record))
#    1089 if skipped:
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:969, in VerboseTB.format_record(self, frame_info)
#     966     # result += "\n".join(frame_info.raw_lines)
#     967 else:
#     968     result += "".join(
# --> 969         _format_traceback_lines(
#     970             frame_info.lines, Colors, self.has_colors, lvals
#     971         )
#     972     )
#     973 return result
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:215, in _format_traceback_lines(lines, Colors, has_colors, lvals)
#     213     continue
# --> 215 line = stack_line.render(pygmented=has_colors).rstrip('\n') + '\n'
#     216 lineno = stack_line.lineno
#
# File /usr/lib/python3/dist-packages/stack_data/core.py:391, in Line.render(self, markers, strip_leading_indent, pygmented, escape_html)
#     390 assert_(not markers, ValueError("Cannot use pygmented with markers"))
# --> 391 start_line, lines = self.frame_info._pygmented_scope_lines
#     392 result = lines[self.lineno - start_line]
#
# File /usr/lib/python3/dist-packages/stack_data/utils.py:145, in cached_property.cached_property_wrapper(self, obj, _cls)
#     143     return self
# --> 145 value = obj.__dict__[self.func.__name__] = self.func(obj)
#     146 return value
#
# File /usr/lib/python3/dist-packages/stack_data/core.py:824, in FrameInfo._pygmented_scope_lines(self)
#     823 code = atext.get_text(scope)
# --> 824 lines = _pygmented_with_ranges(formatter, code, ranges)
#     826 start_line = self.source.line_range(scope)[0]
#
# File /usr/lib/python3/dist-packages/stack_data/utils.py:164, in _pygmented_with_ranges(formatter, code, ranges)
#     162             yield ttype, value
# --> 164 lexer = MyLexer(stripnl=False)
#     165 try:
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:657, in RegexLexerMeta.__call__(cls, *args, **kwds)
#     656     else:
# --> 657         cls._tokens = cls.process_tokendef('', cls.get_tokendefs())
#     659 return type.__call__(cls, *args, **kwds)
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:596, in RegexLexerMeta.process_tokendef(cls, name, tokendefs)
#     595 for state in list(tokendefs):
# --> 596     cls._process_state(tokendefs, processed, state)
#     597 return processed
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:559, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     558 assert tdef != state, "circular state reference %r" % state
# --> 559 tokens.extend(cls._process_state(unprocessed, processed,
#     560                                  str(tdef)))
#     561 continue
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:559, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     558 assert tdef != state, "circular state reference %r" % state
# --> 559 tokens.extend(cls._process_state(unprocessed, processed,
#     560                                  str(tdef)))
#     561 continue
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:575, in RegexLexerMeta._process_state(cls, unprocessed, processed, state)
#     574 try:
# --> 575     rex = cls._process_regex(tdef[0], rflags, state)
#     576 except Exception as err:
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:503, in RegexLexerMeta._process_regex(cls, regex, rflags, state)
#     502 if isinstance(regex, Future):
# --> 503     regex = regex.get()
#     504 return re.compile(regex, rflags).match
#
# File /usr/lib/python3/dist-packages/pygments/lexer.py:491, in words.get(self)
#     490 def get(self):
# --> 491     return regex_opt(self.words, prefix=self.prefix, suffix=self.suffix)
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:91, in regex_opt(strings, prefix, suffix)
#      90 strings = sorted(strings)
# ---> 91 return prefix + regex_opt_inner(strings, '(') + suffix
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:77, in regex_opt_inner(strings, open_paren)
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:77, in <genexpr>(.0)
#      74 # recurse on common 1-string prefixes
#      75 # print '-> last resort'
#      76 return open_paren + \
# ---> 77     '|'.join(regex_opt_inner(list(group[1]), '')
#      78              for group in groupby(strings, lambda s: s[0] == first[0])) \
#      79     + close_paren
#
# File /usr/lib/python3/dist-packages/pygments/regexopt.py:57, in regex_opt_inner(strings, open_paren)
#      56         return open_paren + make_charset(oneletter) + close_paren
# ---> 57 prefix = commonprefix(strings)
#      58 if prefix:
#
# File /usr/lib/python3.12/genericpath.py:90, in commonprefix(m)
#      89     m = tuple(map(os.fspath, m))
# ---> 90 s1 = min(m)
#      91 s2 = max(m)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3493, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3492     asy = compare(code)
# -> 3493 if await self.run_code(code, result, async_=asy):
#    3494     return True
#
#     [... skipping hidden 1 frame]
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2165, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2164 except KeyboardInterrupt:
# -> 2165     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2088, in InteractiveShell.get_exception_only(self, exc_tuple)
#    2087 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2088 msg = traceback.format_exception_only(etype, value)
#    2089 return ''.join(msg)
#
# File /usr/lib/python3.12/traceback.py:156, in format_exception_only(exc, value)
#     155     value = exc
# --> 156 te = TracebackException(type(value), value, None, compact=True)
#     157 return list(te.format_exception_only())
#
# File /usr/lib/python3.12/traceback.py:811, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     809 if (e and e.__context__ is not None
#     810     and need_context and id(e.__context__) not in _seen):
# --> 811     context = TracebackException(
#     812         type(e.__context__),
#     813         e.__context__,
#     814         e.__context__.__traceback__,
#     815         limit=limit,
#     816         lookup_lines=lookup_lines,
#     817         capture_locals=capture_locals,
#     818         max_group_width=max_group_width,
#     819         max_group_depth=max_group_depth,
#     820         _seen=_seen)
#     821 else:
#
# File /usr/lib/python3.12/traceback.py:733, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     731 self.max_group_depth = max_group_depth
# --> 733 self.stack = StackSummary._extract_from_extended_frame_gen(
#     734     _walk_tb_with_full_positions(exc_traceback),
#     735     limit=limit, lookup_lines=lookup_lines,
#     736     capture_locals=capture_locals)
#     737 self.exc_type = exc_type
#
# File /usr/lib/python3.12/traceback.py:434, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     433 for filename in fnames:
# --> 434     linecache.checkcache(filename)
#     435 # If immediate lookup was desired, trigger lookups now.
#
# File /usr/lib/python3.12/linecache.py:72, in checkcache(filename)
#      71 try:
# ---> 72     stat = os.stat(fullname)
#      73 except OSError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2144, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2143     else:
# -> 2144         stb = self.InteractiveTB.structured_traceback(
#    2145             etype, value, tb, tb_offset=tb_offset
#    2146         )
#    2148 except Exception:
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1172 """Return a nice text document describing the traceback."""
# -> 1173 formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                        tb_offset)
#    1176 colors = self.Colors  # just a shorthand + quicker name lookup
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:1138, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1137             continue
# -> 1138     max_len = get_line_number_of_frame(cf.tb_frame)
#    1140 except OSError:
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:184, in get_line_number_of_frame(frame)
#     183     return first + len(lines)
# --> 184 return count_lines_in_py_file(filename)
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:150, in count_lines_in_py_file(filename)
#     149     with open(filename, "r") as file:
# --> 150         s = sum(1 for line in file)
#     151 except UnicodeError:
#
# File /usr/lib/python3/dist-packages/IPython/core/ultratb.py:150, in <genexpr>(.0)
#     149     with open(filename, "r") as file:
# --> 150         s = sum(1 for line in file)
#     151 except UnicodeError:
#
# File /usr/lib/python3.12/codecs.py:319, in BufferedIncrementalDecoder.decode(self, input, final)
#     317     raise NotImplementedError
# --> 319 def decode(self, input, final=False):
#     320     # decode input (taking the buffer into account)
#     321     data = self.buffer + input
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3311, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3307 # Execute the user code
#    3308 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3311 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3312        interactivity=interactivity, compiler=compiler, result=result)
#    3314 self.last_execution_succeeded = not has_raised
#    3315 self.last_execution_result = result
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3512, in InteractiveShell.run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3510     if result:
#    3511         result.error_before_exec = sys.exc_info()[1]
# -> 3512     self.showtraceback()
#    3513     return True
#    3515 return False
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2165, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2162         self._showtraceback(etype, value, stb)
#    2164 except KeyboardInterrupt:
# -> 2165     print('\n' + self.get_exception_only(), file=sys.stderr)
#
# File /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:2088, in InteractiveShell.get_exception_only(self, exc_tuple)
#    2083 """
#    2084 Return as a string (ending with a newline) the exception that
#    2085 just occurred, without any traceback.
#    2086 """
#    2087 etype, value, tb = self._get_exc_info(exc_tuple)
# -> 2088 msg = traceback.format_exception_only(etype, value)
#    2089 return ''.join(msg)
#
# File /usr/lib/python3.12/traceback.py:156, in format_exception_only(exc, value)
#     154 if value is _sentinel:
#     155     value = exc
# --> 156 te = TracebackException(type(value), value, None, compact=True)
#     157 return list(te.format_exception_only())
#
# File /usr/lib/python3.12/traceback.py:811, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     808     need_context = True
#     809 if (e and e.__context__ is not None
#     810     and need_context and id(e.__context__) not in _seen):
# --> 811     context = TracebackException(
#     812         type(e.__context__),
#     813         e.__context__,
#     814         e.__context__.__traceback__,
#     815         limit=limit,
#     816         lookup_lines=lookup_lines,
#     817         capture_locals=capture_locals,
#     818         max_group_width=max_group_width,
#     819         max_group_depth=max_group_depth,
#     820         _seen=_seen)
#     821 else:
#     822     context = None
#
# File /usr/lib/python3.12/traceback.py:733, in TracebackException.__init__(self, exc_type, exc_value, exc_traceback, limit, lookup_lines, capture_locals, compact, max_group_width, max_group_depth, _seen)
#     730 self.max_group_width = max_group_width
#     731 self.max_group_depth = max_group_depth
# --> 733 self.stack = StackSummary._extract_from_extended_frame_gen(
#     734     _walk_tb_with_full_positions(exc_traceback),
#     735     limit=limit, lookup_lines=lookup_lines,
#     736     capture_locals=capture_locals)
#     737 self.exc_type = exc_type
#     738 # Capture now to permit freeing resources: only complication is in the
#     739 # unofficial API _format_final_exc_line
#
# File /usr/lib/python3.12/traceback.py:438, in StackSummary._extract_from_extended_frame_gen(klass, frame_gen, limit, lookup_lines, capture_locals)
#     436 if lookup_lines:
#     437     for f in result:
# --> 438         f.line
#     439 return result
#
# File /usr/lib/python3.12/traceback.py:323, in FrameSummary.line(self)
#     321     if self.lineno is None:
#     322         return None
# --> 323     self._line = linecache.getline(self.filename, self.lineno)
#     324 return self._line.strip()
#
# File /usr/lib/python3.12/linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File /usr/lib/python3.12/linecache.py:46, in getlines(filename, module_globals)
#      43         return cache[filename][2]
#      45 try:
# ---> 46     return updatecache(filename, module_globals)
#      47 except MemoryError:
#      48     clearcache()
#
# File /usr/lib/python3.12/linecache.py:136, in updatecache(filename, module_globals)
#     134         return []
#     135 try:
# --> 136     with tokenize.open(fullname) as fp:
#     137         lines = fp.readlines()
#     138 except (OSError, UnicodeDecodeError, SyntaxError):
#
# File /usr/lib/python3.12/tokenize.py:449, in open(filename)
#     445 def open(filename):
#     446     """Open a file in read only mode using the encoding detected by
#     447     detect_encoding().
#     448     """
# --> 449     buffer = _builtin_open(filename, 'rb')
#     450     try:
#     451         encoding, lines = detect_encoding(buffer.readline)
#
# KeyboardInterrupt:
# /tmp/ipykernel_43435/531882864.py:64: RuntimeWarning: overflow encountered in scalar power
#   return mgf_truncated_normal(mu, sigma, l, u, t) ** T_value
# /tmp/ipykernel_43435/531882864.py:64: RuntimeWarning: overflow encountered in scalar power
#   return mgf_truncated_normal(mu, sigma, l, u, t) ** T_value

# %%
from random import randrange
import math
listofvalues = []
while (len(listofvalues) <50):
    T_value = 60000
    #lamda = randrange(10)
    epsilon = 1
    delta = 1e-5
    sensitivity = 2 
    k = 1#randrange(500)/100+0.000001
    theta = 1#randrange(500)/100 
    a = 0
    b = 1
    mu = randrange(500)/100 
    sigma = randrange(500)/100
    l = randrange(500)/100
    u  = randrange(500)/100
    best_params = None
    best_value = -np.inf
    min_lemma1 = float('inf')
        
    if b > a and u > l and sigma > 0 and theta > 0:
        
        obj_value = objective_function(k, theta, a, b, mu, sigma, l, u)
        
        for i in range(1,100):
            lamda = i

            # Compute the terms in the numerator
            try:
                term1 = (lamda + 1) * MGF_PLRV(k, theta, a, b, mu, sigma, l, u, T_value, lamda * sensitivity)
                term2 = lamda * MGF_PLRV(k, theta, a, b, mu, sigma, l, u, T_value, -(lamda + 1) * sensitivity)
            except: 
                #print("Except1")
                continue
            numerator = term1 + term2

            # Compute the denominator
            denominator = (2 * lamda + 1) * np.exp(lamda * (epsilon))

            # Compute delta for the current lambda
            lemma1 = numerator / denominator
            try:
                maf = math.log((numerator * np.exp(lamda * (epsilon))) / denominator)
            except:
                #print("Except2")
                continue
                
            test_ep = (math.log(1/delta)+maf)/lamda
            #print(test_ep)
            L = obj_value# - (lemma1)
            if (not math.isnan(test_ep)) and test_ep <= epsilon*0.008 and test_ep > 0: #and test_ep <= epsilon/T_value:
                listofvalues.append([lamda, sensitivity, k, theta, a, b, mu, sigma, l, u])
                print(len(listofvalues))
            else:
                L = -np.inf

                # Keep track of the minimum delta
            if L > best_value:
                best_value = L
                best_params = {'epsilon': epsilon, 'T': T_value, 'sensitivity': sensitivity, 'k': k, 'theta': theta, 'a': a, 'b': b, 'mu': mu, 'sigma': sigma, 'l': l, 'u': u, 'lambda': lamda}
# Out:
# /tmp/ipykernel_43435/531882864.py:60: RuntimeWarning: overflow encountered in exp
#   return np.exp((mu * t + 0.5 * sigma ** 2 * t ** 2)/2) * num / den
# /tmp/ipykernel_43435/531882864.py:60: RuntimeWarning: invalid value encountered in scalar multiply
#   return np.exp((mu * t + 0.5 * sigma ** 2 * t ** 2)/2) * num / den
# /tmp/ipykernel_43435/531882864.py:41: RuntimeWarning: divide by zero encountered in scalar divide
#   normal_expect = mu + sigma * (norm.pdf((l - mu) / sigma) - norm.pdf((u - mu) / sigma)) / (norm.cdf((u - mu) / sigma) - norm.cdf((l - mu) / sigma))
# /tmp/ipykernel_43435/531882864.py:60: RuntimeWarning: invalid value encountered in scalar divide
#   return np.exp((mu * t + 0.5 * sigma ** 2 * t ** 2)/2) * num / den
# /tmp/ipykernel_43435/531882864.py:60: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.exp((mu * t + 0.5 * sigma ** 2 * t ** 2)/2) * num / den
# /tmp/ipykernel_43435/531882864.py:41: RuntimeWarning: invalid value encountered in scalar divide
#   normal_expect = mu + sigma * (norm.pdf((l - mu) / sigma) - norm.pdf((u - mu) / sigma)) / (norm.cdf((u - mu) / sigma) - norm.cdf((l - mu) / sigma))

# %%
listofvalues

# %%
lamda, sensitivity, k, theta, a, b, mu, sigma, l, u

# %%
listofvalues

# %%
lamda, sensitivity, k, theta, a, b, mu, sigma, l, u

# %%
best_params
# Out:
# {'epsilon': 1,
#  'T': 1000,
#  'sensitivity': 2,
#  'k': 1,
#  'theta': 1,
#  'a': 0,
#  'b': 1,
#  'mu': 2.75,
#  'sigma': 0.82,
#  'l': 2.37,
#  'u': 2.86,
#  'lambda': 4}
